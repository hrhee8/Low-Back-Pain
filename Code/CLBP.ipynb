# %%
#To check if the patient visitied more than 2 times within 12 week period

import pandas as pd
import os

Desktop = os.path.join(os.path.expanduser("~"), "Desktop")

filepath_root = os.path.join(Desktop, "LBP_Revision")
inclusion_root = os.path.join(filepath_root, "Inclusion_Codes") #inclusion code location
filtered_root = os.path.join(filepath_root, "Filtered_Files") #Filtered data location (Filtered data aggregated all diagnosis by patient)
unfiltered_root = os.path.join(filepath_root, "All_csv_files") #unfiltered data location
combined_root = os.path.join(filepath_root, "LBP_X_Files") #LBP + X filtered location
classify_root = os.path.join(filepath_root, "Sorted_Files") #6 groups location


os.path.exists(filepath_root)

path_inclusion_crit_LBP = os.path.join(inclusion_root,'inclusion_codes_LBP.xlsx')
path_inclusion_crit_DJD = os.path.join(inclusion_root,'inclusion_codes_DJD.xlsx')
path_inclusion_crit_fracture = os.path.join(inclusion_root,'inclusion_codes_fracture.xlsx')
path_inclusion_crit_other = os.path.join(inclusion_root,'inclusion_codes_other.xlsx')
path_inclusion_crit_scoliosis = os.path.join(inclusion_root,'inclusion_codes_scoliosis.xlsx')

# %%
def get_cpts_fromfile(filepath=''):
    df_cpt = pd.read_excel(filepath, dtype=str, sheet_name='CPT Codes')
    return df_cpt['CPT Code']       

def get_icds_fromfile(filepath=''):        
    df_icd = pd.read_excel(filepath,dtype=str, sheet_name='ICD Codes')
    return df_icd['ICD Code']

# %%
LBP_DJD_filename = 'LBP_DJD_patients'
LBP_fracture_filename = 'LBP_fracture_patients'
LBP_other_filename = 'LBP_other_patients'
LBP_scoliosis_filename = 'LBP_scoliosis_patients'
LBP_other_scoliosis_filename = 'LBP_other_scoliosis_patients'
LBP_DJD_data = pd.read_csv(combined_root + '/' + LBP_DJD_filename + '.csv', encoding = 'utf8',dtype=str, index_col=0)
LBP_fracture_data = pd.read_csv(combined_root + '/' + LBP_fracture_filename + '.csv', encoding = 'utf8',dtype=str, index_col=0)
LBP_other_data = pd.read_csv(combined_root + '/' + LBP_other_filename + '.csv', encoding = 'utf8',dtype=str, index_col=0)
LBP_scoliosis_data = pd.read_csv(combined_root + '/' + LBP_scoliosis_filename + '.csv', encoding = 'utf8',dtype=str, index_col=0)
LBP_other_scoliosis_data = pd.read_csv(combined_root + '/' + LBP_other_scoliosis_filename + '.csv', encoding = 'utf8',dtype=str, index_col=0)

LBP_all_data = pd.read_csv(unfiltered_root + '/' + 'LBP_all.csv', encoding = 'utf8',dtype=str)
DJD_all_data = pd.read_csv(unfiltered_root + '/' + 'DJD_all.csv', encoding = 'utf8',dtype=str)
fracture_all_data = pd.read_csv(unfiltered_root + '/' + 'fracture_all.csv', encoding = 'utf8',dtype=str)
other_all_data = pd.read_csv(unfiltered_root + '/' + 'other_all.csv', encoding = 'utf8',dtype=str)
scoliosis_all_data = pd.read_csv(unfiltered_root + '/' + 'scoliosis_all.csv', encoding = 'utf8',dtype=str)

# %%
len(LBP_all_data)

LBP_filtered_data = pd.read_csv(filtered_root + '/' + 'LBP_patients.csv', encoding = 'utf8',dtype=str, index_col=0)
DJD_filtered_data = pd.read_csv(filtered_root + '/' + 'DJD_patients.csv', encoding = 'utf8',dtype=str, index_col=0)
fracture_filtered_data = pd.read_csv(filtered_root + '/' + 'fracture_patients.csv', encoding = 'utf8',dtype=str, index_col=0)
other_filtered_data = pd.read_csv(filtered_root + '/' + 'other_patients.csv', encoding = 'utf8',dtype=str, index_col=0)
scoliosis_filtered_data = pd.read_csv(filtered_root + '/' + 'scoliosis_patients.csv', encoding = 'utf8',dtype=str, index_col=0)

# %%
LBP_all_data['EMPI'] = LBP_all_data['EMPI'].astype(int)
#LBP_all_data['MGH_MRN'] = LBP_all_data['MGH_MRN'].astype(int)

# %%
#Sort the table based on EMPI number and the dates
LBP_all_data = LBP_all_data.sort_values(by = ['EMPI','Date.prc'],ignore_index=True)
LBP_all_data.drop_duplicates()
# Out:
#             EMPI  MGH_MRN  Date.prc  Date.dia Code_Type.prc Code.prc  \
# 0      100000152  1652900   5/28/17   5/31/17           CPT    72100
# 1      100000243   975324   5/16/16   5/16/16           CPT    72040
# 2      100000243   975324   5/16/16   5/16/16           CPT    72040
# 3      100001760  1705078   6/26/20   7/16/20           CPT    72040
# 4      100003506  2942724   1/24/17   1/24/17           CPT    72100
# ...          ...      ...       ...       ...           ...      ...
# 14220  115653907  7472359    6/7/21    6/7/21           CPT    72100
# 14221  115676474  7508548  12/14/21  12/14/21           CPT    72100
# 14222  115676474  7508548  12/14/21  12/14/21           CPT    72100
# 14223  115786989  7623943    8/1/19    8/1/19           CPT    72100
# 14224  115786989  7623943    8/1/19    8/1/19           CPT    72100
#
#       Code_Type.dia Code.dia          Diagnosis_Name  \
# 0             ICD10   G89.29      Other chronic pain
# 1             ICD10    M54.9  Dorsalgia, unspecified
# 2             ICD10    M54.9  Dorsalgia, unspecified
# 3             ICD10   G89.29      Other chronic pain
# 4             ICD10    M54.9  Dorsalgia, unspecified
# ...             ...      ...                     ...
# 14220         ICD10    M54.9  Dorsalgia, unspecified
# 14221         ICD10   G89.29      Other chronic pain
# 14222         ICD10   G89.29      Other chronic pain
# 14223         ICD10    M54.9  Dorsalgia, unspecified
# 14224         ICD10    M54.9  Dorsalgia, unspecified
#
#                                           Procedure_Name  ...  \
# 0      Radiologic examination, spine, lumbosacral; tw...  ...
# 1      Radiologic examination, spine, cervical; two o...  ...
# 2      Radiologic examination, spine, cervical; two o...  ...
# 3      Radiologic examination, spine, cervical; two o...  ...
# 4      Radiologic examination, spine, lumbosacral; tw...  ...
# ...                                                  ...  ...
# 14220  Radiologic examination, spine, lumbosacral; tw...  ...
# 14221  Radiologic examination, spine, lumbosacral; tw...  ...
# 14222  Radiologic examination, spine, lumbosacral; tw...  ...
# 14223  Radiologic examination, spine, lumbosacral; tw...  ...
# 14224  Radiologic examination, spine, lumbosacral; tw...  ...
#
#                   Insurance_2                     Insurance_3 Phone_Code  \
# 0      BLUE CROSS BLUE SHIELD                        MEDICARE        617
# 1                    MEDICARE                     UNICARE GIC        781
# 2                    MEDICARE                     UNICARE GIC        781
# 3      BLUE CROSS BLUE SHIELD                        MEDICARE        508
# 4             HARVARD PILGRIM  MASS BLUE CROSS/MASTER MEDICAL        617
# ...                       ...                             ...        ...
# 14220       HEALTH SAFETY NET                      MASSHEALTH        781
# 14221       UNITED HEALTHCARE      MEDICAID NON MASSACHUSETTS        207
# 14222       UNITED HEALTHCARE      MEDICAID NON MASSACHUSETTS        207
# 14223         HARVARD PILGRIM                 HARVARD PILGRIM        617
# 14224         HARVARD PILGRIM                 HARVARD PILGRIM        617
#
#       Physical_Date    BMI  Height     Weight  \
# 0           5/17/17  27.02  154.94  64.863656
# 1           5/16/16  24.73  156.21  60.327736
# 2           5/16/16  24.73  156.21  60.327736
# 3           6/26/20    NaN     NaN        NaN
# 4           1/24/17  20.06     NaN   58.96696
# ...             ...    ...     ...        ...
# 14220       6/20/21    NaN     NaN        NaN
# 14221        2/2/22    NaN     NaN        NaN
# 14222        2/2/22    NaN     NaN        NaN
# 14223       7/26/19   34.2  158.75   86.18248
# 14224       7/26/19   34.2  158.75   86.18248
#
#                                 Smoking                 Alcohol_Use  Helper
# 0      Smokeless Tobacco Use-Never Used             Alcohol User-No  useful
# 1         Smokeless Tobacco Use-Unknown             Alcohol User-No     NaN
# 2         Smokeless Tobacco Use-Unknown             Alcohol User-No  useful
# 3                                   NaN                         NaN  useful
# 4      Smokeless Tobacco Use-Never Used             Alcohol User-No     NaN
# ...                                 ...                         ...     ...
# 14220  Smoking Tobacco Use-Never Smoker  Alcohol User-Not Currently     NaN
# 14221  Smokeless Tobacco Use-Never Used            Alcohol User-Yes     NaN
# 14222  Smokeless Tobacco Use-Never Used            Alcohol User-Yes  useful
# 14223  Smokeless Tobacco Use-Never Used  Alcohol User-Not Currently     NaN
# 14224  Smokeless Tobacco Use-Never Used  Alcohol User-Not Currently  useful
#
# [14225 rows x 39 columns]

# %%
#Creating column "Date_combined" to view what dates the patients visited
LBP_all_data['Date_combined'] = str(0)

LBP_all_data.loc[0,'Date_combined'] = LBP_all_data.loc[0,'Date.prc']
for i in range(1,len(LBP_all_data)):
    if LBP_all_data.loc[i,'EMPI'] == LBP_all_data.loc[i-1,'EMPI']:
        if LBP_all_data.loc[i,'Date.prc'] != LBP_all_data.loc[i-1,'Date.prc']:
            LBP_all_data.loc[i,'Date_combined'] = str(LBP_all_data.loc[i,'Date.prc']) + ', ' + str(LBP_all_data.loc[i-1,'Date_combined'])
            continue;
        else: 
            LBP_all_data.loc[i,'Date_combined'] = str(LBP_all_data.loc[i-1,'Date_combined'])
            continue;
    else: 
        LBP_all_data.loc[i,'Date_combined'] = str(LBP_all_data.loc[i,'Date.prc'])
        continue;

# %% [markdown]
# NOT DONE YET!
# Potential work: It would be nice to see how many visits the patients had on a separate column

# %%
#LBP_all_data.loc[2,'EMPI']
#LBP_all_data.loc[1,'Date_combined']
LBP_all_data.head(10)
# Out:
#         EMPI  MGH_MRN Date.prc Date.dia Code_Type.prc Code.prc Code_Type.dia  \
# 0  100000152  1652900  5/28/17  5/31/17           CPT    72100         ICD10
# 1  100000243   975324  5/16/16  5/16/16           CPT    72040         ICD10
# 2  100000243   975324  5/16/16  5/16/16           CPT    72040         ICD10
# 3  100001760  1705078  6/26/20  7/16/20           CPT    72040         ICD10
# 4  100003506  2942724  1/24/17  1/24/17           CPT    72100         ICD10
# 5  100003506  2942724  1/24/17  1/24/17           CPT    72100         ICD10
# 6  100004276  1172734  3/18/16  3/18/16           CPT    72100         ICD10
# 7  100004276  1172734  3/18/16  3/18/16           CPT    72100         ICD10
# 8  100004276  1172734   6/4/19  8/29/19           CPT    72040         ICD10
# 9  100004276  1172734   6/4/19  8/29/19           CPT    72040         ICD10
#
#   Code.dia          Diagnosis_Name  \
# 0   G89.29      Other chronic pain
# 1    M54.9  Dorsalgia, unspecified
# 2    M54.9  Dorsalgia, unspecified
# 3   G89.29      Other chronic pain
# 4    M54.9  Dorsalgia, unspecified
# 5    M54.9  Dorsalgia, unspecified
# 6    M54.9  Dorsalgia, unspecified
# 7    M54.9  Dorsalgia, unspecified
# 8   G89.29      Other chronic pain
# 9   G89.29      Other chronic pain
#
#                                       Procedure_Name  ...  \
# 0  Radiologic examination, spine, lumbosacral; tw...  ...
# 1  Radiologic examination, spine, cervical; two o...  ...
# 2  Radiologic examination, spine, cervical; two o...  ...
# 3  Radiologic examination, spine, cervical; two o...  ...
# 4  Radiologic examination, spine, lumbosacral; tw...  ...
# 5  Radiologic examination, spine, lumbosacral; tw...  ...
# 6  Radiologic examination, spine, lumbosacral; tw...  ...
# 7  Radiologic examination, spine, lumbosacral; tw...  ...
# 8  Radiologic examination, spine, cervical; two o...  ...
# 9  Radiologic examination, spine, cervical; two o...  ...
#
#                       Insurance_3 Phone_Code Physical_Date    BMI  Height  \
# 0                        MEDICARE        617       5/17/17  27.02  154.94
# 1                     UNICARE GIC        781       5/16/16  24.73  156.21
# 2                     UNICARE GIC        781       5/16/16  24.73  156.21
# 3                        MEDICARE        508       6/26/20    NaN     NaN
# 4  MASS BLUE CROSS/MASTER MEDICAL        617       1/24/17  20.06     NaN
# 5  MASS BLUE CROSS/MASTER MEDICAL        617       1/24/17  20.06     NaN
# 6             MEDICARE A/B CLAIMS        617        1/5/16  21.15   152.4
# 7             MEDICARE A/B CLAIMS        617        1/5/16  21.15   152.4
# 8             MEDICARE A/B CLAIMS        617       5/23/19  17.51     NaN
# 9             MEDICARE A/B CLAIMS        617       5/23/19  17.51     NaN
#
#        Weight                             Smoking       Alcohol_Use  Helper  \
# 0   64.863656    Smokeless Tobacco Use-Never Used   Alcohol User-No  useful
# 1   60.327736       Smokeless Tobacco Use-Unknown   Alcohol User-No     NaN
# 2   60.327736       Smokeless Tobacco Use-Unknown   Alcohol User-No  useful
# 3         NaN                                 NaN               NaN  useful
# 4    58.96696    Smokeless Tobacco Use-Never Used   Alcohol User-No     NaN
# 5    58.96696    Smokeless Tobacco Use-Never Used   Alcohol User-No  useful
# 6  49.1240136  Smokeless Tobacco Use-Current User  Alcohol User-Yes     NaN
# 7  49.1240136  Smokeless Tobacco Use-Current User  Alcohol User-Yes  useful
# 8   46.266384    Smokeless Tobacco Use-Never Used  Alcohol User-Yes     NaN
# 9   46.266384    Smokeless Tobacco Use-Never Used  Alcohol User-Yes  useful
#
#      Date_combined
# 0          5/28/17
# 1          5/16/16
# 2          5/16/16
# 3          6/26/20
# 4          1/24/17
# 5          1/24/17
# 6          3/18/16
# 7          3/18/16
# 8  6/4/19, 3/18/16
# 9  6/4/19, 3/18/16
#
# [10 rows x 40 columns]

# %%
type(LBP_all_data.loc[1,'Date.prc'])
dt = pd.to_datetime(LBP_all_data.loc[8,'Date.prc'], format='%m/%d/%y')
dt_first = pd.to_datetime(LBP_all_data.loc[7,'Date.prc'], format='%m/%d/%y')
time_diff = (dt-dt_first).days
print(dt)
print(dt_first)
print(time_diff)
if time_diff > 84:
    print('yes')
else:
    print('no')
# Out:
# 2019-06-04 00:00:00
# 2016-03-18 00:00:00
# 1173
# yes

# %%
LBP_all_data.loc[0,'Date_combined'] = LBP_all_data.loc[0,'Date.prc'] # Not really important line

#This checks if the patient had 2 visits 
first_encounter_EMPI = 0
first_encounter_index = 0
for i in range(1,len(LBP_all_data)):
#for i in range(1,10):
    if LBP_all_data.loc[i,'EMPI'] == first_encounter_EMPI:
        dt = pd.to_datetime(LBP_all_data.loc[i,'Date.prc'], format='%m/%d/%y') 
        # Because the EMPI sorted, if there are additional visits it would be existing in the following row
        dt_first = pd.to_datetime(LBP_all_data.loc[first_encounter_index,'Date.prc'], format='%m/%d/%y')
        time_diff = (dt-dt_first).days
        #print(i, time_diff)
        LBP_all_data.loc[i,'Date_diff'] = time_diff
        if time_diff >= 84:
            LBP_all_data.loc[i,'CLBP'] = 'Yes'
        elif time_diff == 0:
            LBP_all_data.loc[i,'CLBP'] = 'Same_day'
        else:
            LBP_all_data.loc[i,'CLBP'] = 'No'
    else:
        first_encounter_EMPI = LBP_all_data.loc[i,'EMPI']
        first_encounter_index = i

# %%
CLBP_No = LBP_all_data[LBP_all_data["CLBP"] == 'No']
CLBP_No_first_visit = CLBP_No.groupby('EMPI', as_index=False).nth(0)
#CLBP_No = CLBP_No[CLBP_No['Helper'] == 'useful']

# %%
CLBP_No_first_visit.head()
# Out:
#          EMPI  MGH_MRN  Date.prc  Date.dia Code_Type.prc Code.prc  \
# 14  100006144  2414487  11/16/16   12/6/16           CPT    72100
# 40  100008826  4130303   11/7/18   11/7/18           CPT    72020
# 48  100009735  4388695    7/9/18   9/14/18           CPT    72100
# 52  100010159  1500455   5/29/18   5/29/18           CPT    72100
# 62  100011347  6226731  11/24/17  11/24/17           CPT    72100
#
#    Code_Type.dia Code.dia                                     Diagnosis_Name  \
# 14         ICD10   G89.29                                 Other chronic pain
# 40         ICD10   G89.29                                 Other chronic pain
# 48         ICD10   G89.29                                 Other chronic pain
# 52         ICD10   M51.26  Other intervertebral disc displacement, lumbar...
# 62         ICD10    M54.9                             Dorsalgia, unspecified
#
#                                        Procedure_Name  ... Physical_Date  \
# 14  Radiologic examination, spine, lumbosacral; tw...  ...      10/18/16
# 40  Radiologic examination, spine, single view, sp...  ...      12/27/18
# 48  Radiologic examination, spine, lumbosacral; tw...  ...       7/13/18
# 52  Radiologic examination, spine, lumbosacral; tw...  ...       5/29/18
# 62  Radiologic examination, spine, lumbosacral; tw...  ...      11/20/17
#
#       BMI     Height      Weight                            Smoking  \
# 14  23.33     170.18   67.585208                  Tobacco User-Quit
# 40  21.46     170.18   62.142104   Smokeless Tobacco Use-Never Used
# 48  47.13        NaN  149.004972   Smokeless Tobacco Use-Never Used
# 52  18.62  170.20032  53.9320888  Smoking Tobacco Use-Former Smoker
# 62    NaN        NaN         NaN   Smokeless Tobacco Use-Never Used
#
#                Alcohol_Use Helper       Date_combined Date_diff CLBP
# 14  Alcohol User-Not Asked    NaN  11/16/16, 10/18/16      29.0   No
# 40        Alcohol User-Yes    NaN   11/7/18, 11/27/18     -20.0   No
# 48         Alcohol User-No    NaN     7/9/18, 6/22/18      17.0   No
# 52        Alcohol User-Yes    NaN    5/29/18, 4/10/18      49.0   No
# 62         Alcohol User-No    NaN  11/24/17, 11/22/17       2.0   No
#
# [5 rows x 42 columns]

# %%
print(len(LBP_all_data),len(CLBP_No))
print(len(pd.unique(LBP_all_data['EMPI'])))
print(len(pd.unique(CLBP_No['EMPI'])))
# Out:
# 14225 3790
# 4321
# 1122

# %%
Non_CLBP = LBP_all_data[LBP_all_data['CLBP'].isnull()]
Non_CLBP.head()
Non_CLBP_first_visit = CLBP_No.groupby('EMPI', as_index=False).nth(0)

# %%
print(len(Non_CLBP),len(CLBP_No))
Non_CLBP_control = pd.concat([Non_CLBP,CLBP_No]) #everything other than CLBP (excluded same day visits)
Non_CLBP_control.head()
# Out:
# 4321 3790
#         EMPI  MGH_MRN Date.prc Date.dia Code_Type.prc Code.prc Code_Type.dia  \
# 0  100000152  1652900  5/28/17  5/31/17           CPT    72100         ICD10
# 1  100000243   975324  5/16/16  5/16/16           CPT    72040         ICD10
# 3  100001760  1705078  6/26/20  7/16/20           CPT    72040         ICD10
# 4  100003506  2942724  1/24/17  1/24/17           CPT    72100         ICD10
# 6  100004276  1172734  3/18/16  3/18/16           CPT    72100         ICD10
#
#   Code.dia          Diagnosis_Name  \
# 0   G89.29      Other chronic pain
# 1    M54.9  Dorsalgia, unspecified
# 3   G89.29      Other chronic pain
# 4    M54.9  Dorsalgia, unspecified
# 6    M54.9  Dorsalgia, unspecified
#
#                                       Procedure_Name  ... Physical_Date  \
# 0  Radiologic examination, spine, lumbosacral; tw...  ...       5/17/17
# 1  Radiologic examination, spine, cervical; two o...  ...       5/16/16
# 3  Radiologic examination, spine, cervical; two o...  ...       6/26/20
# 4  Radiologic examination, spine, lumbosacral; tw...  ...       1/24/17
# 6  Radiologic examination, spine, lumbosacral; tw...  ...        1/5/16
#
#      BMI  Height      Weight                             Smoking  \
# 0  27.02  154.94   64.863656    Smokeless Tobacco Use-Never Used
# 1  24.73  156.21   60.327736       Smokeless Tobacco Use-Unknown
# 3    NaN     NaN         NaN                                 NaN
# 4  20.06     NaN    58.96696    Smokeless Tobacco Use-Never Used
# 6  21.15   152.4  49.1240136  Smokeless Tobacco Use-Current User
#
#         Alcohol_Use  Helper Date_combined Date_diff CLBP
# 0   Alcohol User-No  useful       5/28/17       NaN  NaN
# 1   Alcohol User-No     NaN       5/16/16       NaN  NaN
# 3               NaN  useful       6/26/20       NaN  NaN
# 4   Alcohol User-No     NaN       1/24/17       NaN  NaN
# 6  Alcohol User-Yes     NaN       3/18/16       NaN  NaN
#
# [5 rows x 42 columns]

# %%
CLBP = LBP_all_data[LBP_all_data["CLBP"] == 'Yes']
CLBP = CLBP[CLBP['Helper'] == 'useful']
CLBP.head()
# Out:
#          EMPI  MGH_MRN Date.prc  Date.dia Code_Type.prc Code.prc  \
# 9   100004276  1172734   6/4/19   8/29/19           CPT    72040
# 25  100006144  2414487   7/1/21    7/6/21           CPT    72100
# 55  100010159  1500455   6/5/21    6/5/21           CPT    72100
# 91  100019067  1870877   8/6/18    9/7/18           CPT    72100
# 93  100019067  1870877  9/20/21  11/17/21           CPT    72110
#
#    Code_Type.dia Code.dia          Diagnosis_Name  \
# 9          ICD10   G89.29      Other chronic pain
# 25         ICD10    M54.9  Dorsalgia, unspecified
# 55         ICD10   G89.29      Other chronic pain
# 91         ICD10   G89.29      Other chronic pain
# 93         ICD10    M54.9  Dorsalgia, unspecified
#
#                                        Procedure_Name  ... Physical_Date  \
# 9   Radiologic examination, spine, cervical; two o...  ...       5/23/19
# 25  Radiologic examination, spine, lumbosacral; tw...  ...       1/14/20
# 55  Radiologic examination, spine, lumbosacral; tw...  ...        6/1/21
# 91  Radiologic examination, spine, lumbosacral; tw...  ...       1/29/18
# 93  Radiologic examination, spine, lumbosacral; mi...  ...       10/1/21
#
#       BMI  Height      Weight                           Smoking  \
# 9   17.51     NaN   46.266384  Smokeless Tobacco Use-Never Used
# 25   23.6  170.18  68.3563144                 Tobacco User-Quit
# 55    NaN     NaN         NaN  Smokeless Tobacco Use-Never Used
# 91  27.89  180.34     90.7184  Smoking Tobacco Use-Never Smoker
# 93  27.62  180.34   89.811216  Smokeless Tobacco Use-Never Used
#
#          Alcohol_Use  Helper  \
# 9   Alcohol User-Yes  useful
# 25  Alcohol User-Yes  useful
# 55  Alcohol User-Yes  useful
# 91  Alcohol User-Yes  useful
# 93  Alcohol User-Yes  useful
#
#                                         Date_combined Date_diff CLBP
# 9                                     6/4/19, 3/18/16    1173.0  Yes
# 25  7/1/21, 6/16/21, 4/27/21, 3/5/20, 11/16/16, 10...    1717.0  Yes
# 55                           6/5/21, 5/29/18, 4/10/18    1152.0  Yes
# 91         8/6/18, 5/6/19, 3/25/16, 12/30/16, 1/29/18     189.0  Yes
# 93  9/20/21, 8/6/18, 5/6/19, 3/25/16, 12/30/16, 1/...    1330.0  Yes
#
# [5 rows x 42 columns]

# %%
Project_root = os.path.join(filepath_root, "Project")
root_3_1 = os.path.join(Project_root, "3-1")
root_3_1_CLBP_csv_path = os.path.join(root_3_1,'CLBP.csv')
CLBP.to_csv(root_3_1_CLBP_csv_path)
root_3_1_nonCLBP_csv_path = os.path.join(root_3_1,'Non_CLBP.csv')
Non_CLBP.to_csv(root_3_1_nonCLBP_csv_path)

# %%
root_3_1_nonCLBP_control_csv_path = os.path.join(root_3_1,'Non_CLBP_control.csv')
Non_CLBP_control.to_csv(root_3_1_nonCLBP_control_csv_path)

# %%
print(len(CLBP),len(Non_CLBP))
# Out:
# 636 4321

# %% [markdown]
# things to do
#
# 1. sort the data based on empi or mrn
# 2. congregate the diagnosis code with date
# 3.

# %% [markdown]
# Need to fix on
# 1. diagnosis list of row 8,9 is same, but the cumulative diag list is different, but 8 and 9 are not added together

# %%
duplicate = LBP_all_data[LBP_all_data.duplicated(['EMPI','Date.prc','diagnosis_list'])]
duplicate.head()
# Out:
#           EMPI  MGH_MRN  Date.prc Date.dia Code_Type.prc Code.prc  \
# 15   100006144  2414487  11/16/16  12/6/16           CPT    72100
# 16   100006144  2414487  11/16/16  12/6/16           CPT    72100
# 429  100071445   881204   8/28/17  11/8/17           CPT    72100
# 477  100076350   934283    1/9/20  1/26/20           CPT    72100
# 551  100085624  1027483   3/10/16  3/10/16           CPT    72080
#
#     Code_Type.dia Code.dia          Diagnosis_Name  \
# 15          ICD10   G89.29      Other chronic pain
# 16          ICD10   G89.29      Other chronic pain
# 429         ICD10   G89.29      Other chronic pain
# 477         ICD10    M54.9  Dorsalgia, unspecified
# 551          ICD9    724.5   Backache, unspecified
#
#                                         Procedure_Name  ... Physical_Date  \
# 15   Radiologic examination, spine, lumbosacral; tw...  ...      10/18/16
# 16   Radiologic examination, spine, lumbosacral; tw...  ...      10/18/16
# 429  Radiologic examination, spine, lumbosacral; tw...  ...       7/25/17
# 477  Radiologic examination, spine, lumbosacral; tw...  ...       11/5/19
# 551  Radiologic examination, spine; thoracolumbar, ...  ...       3/18/16
#
#        BMI  Height      Weight                           Smoking  \
# 15   23.33  170.18   67.585208                 Tobacco User-Quit
# 16   23.33  170.18   67.585208                 Tobacco User-Quit
# 429  27.83     NaN   59.874144     Smokeless Tobacco Use-Unknown
# 477  25.61  157.48    63.50288  Smokeless Tobacco Use-Never Used
# 551  42.89  154.94  102.965384     Smokeless Tobacco Use-Unknown
#
#                 Alcohol_Use Helper       Date_combined Date_diff      CLBP
# 15   Alcohol User-Not Asked    NaN  11/16/16, 10/18/16      29.0        No
# 16   Alcohol User-Not Asked    NaN  11/16/16, 10/18/16      29.0        No
# 429         Alcohol User-No    NaN             8/28/17       0.0  Same_day
# 477         Alcohol User-No    NaN              1/9/20       0.0  Same_day
# 551         Alcohol User-No    NaN             3/10/16       0.0  Same_day
#
# [5 rows x 42 columns]

# %%
Non_CLBP_control.head()
# Out:
#         EMPI  MGH_MRN Date.prc Date.dia Code_Type.prc Code.prc Code_Type.dia  \
# 0  100000152  1652900  5/28/17  5/31/17           CPT    72100         ICD10
# 1  100000243   975324  5/16/16  5/16/16           CPT    72040         ICD10
# 3  100001760  1705078  6/26/20  7/16/20           CPT    72040         ICD10
# 4  100003506  2942724  1/24/17  1/24/17           CPT    72100         ICD10
# 6  100004276  1172734  3/18/16  3/18/16           CPT    72100         ICD10
#
#   Code.dia          Diagnosis_Name  \
# 0   G89.29      Other chronic pain
# 1    M54.9  Dorsalgia, unspecified
# 3   G89.29      Other chronic pain
# 4    M54.9  Dorsalgia, unspecified
# 6    M54.9  Dorsalgia, unspecified
#
#                                       Procedure_Name  ... Physical_Date  \
# 0  Radiologic examination, spine, lumbosacral; tw...  ...       5/17/17
# 1  Radiologic examination, spine, cervical; two o...  ...       5/16/16
# 3  Radiologic examination, spine, cervical; two o...  ...       6/26/20
# 4  Radiologic examination, spine, lumbosacral; tw...  ...       1/24/17
# 6  Radiologic examination, spine, lumbosacral; tw...  ...        1/5/16
#
#      BMI  Height      Weight                             Smoking  \
# 0  27.02  154.94   64.863656    Smokeless Tobacco Use-Never Used
# 1  24.73  156.21   60.327736       Smokeless Tobacco Use-Unknown
# 3    NaN     NaN         NaN                                 NaN
# 4  20.06     NaN    58.96696    Smokeless Tobacco Use-Never Used
# 6  21.15   152.4  49.1240136  Smokeless Tobacco Use-Current User
#
#         Alcohol_Use  Helper Date_combined Date_diff CLBP
# 0   Alcohol User-No  useful       5/28/17       NaN  NaN
# 1   Alcohol User-No     NaN       5/16/16       NaN  NaN
# 3               NaN  useful       6/26/20       NaN  NaN
# 4   Alcohol User-No     NaN       1/24/17       NaN  NaN
# 6  Alcohol User-Yes     NaN       3/18/16       NaN  NaN
#
# [5 rows x 42 columns]

# %%
Non_CLBP_control_firstvisit = pd.concat([Non_CLBP_first_visit,CLBP_No_first_visit])
Control_first_visit = Non_CLBP_control_firstvisit.groupby('EMPI', as_index=False).nth(0)
Control_first_visit.head()
print(len(Control_first_visit),len(Non_CLBP_first_visit),len(CLBP_No_first_visit))
# Out:
# 1122 1122 1122

# %%
Control_first_visit_2 = Non_CLBP_control.groupby('EMPI', as_index=False).nth(0) #nonCLBP
print(len(Control_first_visit_2))
Control_first_visit_2.head()
# Out:
# 4321
#         EMPI  MGH_MRN Date.prc Date.dia Code_Type.prc Code.prc Code_Type.dia  \
# 0  100000152  1652900  5/28/17  5/31/17           CPT    72100         ICD10
# 1  100000243   975324  5/16/16  5/16/16           CPT    72040         ICD10
# 3  100001760  1705078  6/26/20  7/16/20           CPT    72040         ICD10
# 4  100003506  2942724  1/24/17  1/24/17           CPT    72100         ICD10
# 6  100004276  1172734  3/18/16  3/18/16           CPT    72100         ICD10
#
#   Code.dia          Diagnosis_Name  \
# 0   G89.29      Other chronic pain
# 1    M54.9  Dorsalgia, unspecified
# 3   G89.29      Other chronic pain
# 4    M54.9  Dorsalgia, unspecified
# 6    M54.9  Dorsalgia, unspecified
#
#                                       Procedure_Name  ... Physical_Date  \
# 0  Radiologic examination, spine, lumbosacral; tw...  ...       5/17/17
# 1  Radiologic examination, spine, cervical; two o...  ...       5/16/16
# 3  Radiologic examination, spine, cervical; two o...  ...       6/26/20
# 4  Radiologic examination, spine, lumbosacral; tw...  ...       1/24/17
# 6  Radiologic examination, spine, lumbosacral; tw...  ...        1/5/16
#
#      BMI  Height      Weight                             Smoking  \
# 0  27.02  154.94   64.863656    Smokeless Tobacco Use-Never Used
# 1  24.73  156.21   60.327736       Smokeless Tobacco Use-Unknown
# 3    NaN     NaN         NaN                                 NaN
# 4  20.06     NaN    58.96696    Smokeless Tobacco Use-Never Used
# 6  21.15   152.4  49.1240136  Smokeless Tobacco Use-Current User
#
#         Alcohol_Use  Helper Date_combined Date_diff CLBP
# 0   Alcohol User-No  useful       5/28/17       NaN  NaN
# 1   Alcohol User-No     NaN       5/16/16       NaN  NaN
# 3               NaN  useful       6/26/20       NaN  NaN
# 4   Alcohol User-No     NaN       1/24/17       NaN  NaN
# 6  Alcohol User-Yes     NaN       3/18/16       NaN  NaN
#
# [5 rows x 42 columns]

# %%
sample_800 = Control_first_visit_2.sample(n = 800) #nonCLBP
root_3_1_Control_csv_path = os.path.join(root_3_1,'800_random_control.csv') #nonCLBP
sample_800.to_csv(root_3_1_Control_csv_path)

# %%
CLBP_diag = CLBP[["EMPI","Code.dia"]]

# %%
CLBP_diag.iloc[1,1]
# Out:
# 'M54.9'

# %%
CLBP_real = CLBP_diag[CLBP_diag["Code.dia"] == 'M54.5']

# %%
CLBP_real.head()
# Out:
# Empty DataFrame
# Columns: [EMPI, Code.dia]
# Index: []

# %%
CLBP_real = CLBP_diag[(CLBP_diag["Code.dia"] == 'M54.5')| (CLBP_diag["Code.dia"] == 'M54.50')]
CLBP_real.head()
# Out:
# Empty DataFrame
# Columns: [EMPI, Code.dia]
# Index: []

# %%
LBP_nonspecific = LBP_all_data[(LBP_all_data["Code.dia"] == 'M54.5')| (LBP_all_data["Code.dia"] == 'M54.9')]
len(LBP_nonspecific)
# Out:
# 5125

# %%
LBP_nonspecific.head()
# Out:
#         EMPI  MGH_MRN Date.prc Date.dia Code_Type.prc Code.prc Code_Type.dia  \
# 1  100000243   975324  5/16/16  5/16/16           CPT    72040         ICD10
# 2  100000243   975324  5/16/16  5/16/16           CPT    72040         ICD10
# 4  100003506  2942724  1/24/17  1/24/17           CPT    72100         ICD10
# 5  100003506  2942724  1/24/17  1/24/17           CPT    72100         ICD10
# 6  100004276  1172734  3/18/16  3/18/16           CPT    72100         ICD10
#
#   Code.dia          Diagnosis_Name  \
# 1    M54.9  Dorsalgia, unspecified
# 2    M54.9  Dorsalgia, unspecified
# 4    M54.9  Dorsalgia, unspecified
# 5    M54.9  Dorsalgia, unspecified
# 6    M54.9  Dorsalgia, unspecified
#
#                                       Procedure_Name  ... Physical_Date  \
# 1  Radiologic examination, spine, cervical; two o...  ...       5/16/16
# 2  Radiologic examination, spine, cervical; two o...  ...       5/16/16
# 4  Radiologic examination, spine, lumbosacral; tw...  ...       1/24/17
# 5  Radiologic examination, spine, lumbosacral; tw...  ...       1/24/17
# 6  Radiologic examination, spine, lumbosacral; tw...  ...        1/5/16
#
#      BMI  Height      Weight                             Smoking  \
# 1  24.73  156.21   60.327736       Smokeless Tobacco Use-Unknown
# 2  24.73  156.21   60.327736       Smokeless Tobacco Use-Unknown
# 4  20.06     NaN    58.96696    Smokeless Tobacco Use-Never Used
# 5  20.06     NaN    58.96696    Smokeless Tobacco Use-Never Used
# 6  21.15   152.4  49.1240136  Smokeless Tobacco Use-Current User
#
#         Alcohol_Use  Helper Date_combined Date_diff      CLBP
# 1   Alcohol User-No     NaN       5/16/16       NaN       NaN
# 2   Alcohol User-No  useful       5/16/16       0.0  Same_day
# 4   Alcohol User-No     NaN       1/24/17       NaN       NaN
# 5   Alcohol User-No  useful       1/24/17       0.0  Same_day
# 6  Alcohol User-Yes     NaN       3/18/16       NaN       NaN
#
# [5 rows x 42 columns]

# %%
LBP_nonspecific_545 = LBP_all_data[LBP_all_data["Code.dia"] == 'M54.5']
LBP_nonspecific_545.head()
# Out:
# Empty DataFrame
# Columns: [EMPI, MGH_MRN, Date.prc, Date.dia, Code_Type.prc, Code.prc, Code_Type.dia, Code.dia, Diagnosis_Name, Procedure_Name, Gender_Legal_Sex, Age, Language, Race1, Marital_status, Religion, Date_Of_Death, AgeAtPrc, Admit_Date, Discharge_Date, Discharge_Disposition, diagnosis_list, Diagnosis_list_combined, Diagnosis_list_no_NA, City, State, Zip, Country, Insurance_1, Insurance_2, Insurance_3, Phone_Code, Physical_Date, BMI, Height, Weight, Smoking, Alcohol_Use, Helper, Date_combined, Date_diff, CLBP]
# Index: []
#
# [0 rows x 42 columns]
